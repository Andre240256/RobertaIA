# %%
import gymnasium as gym
from gymnasium.envs.registration import register
from robertaEnv import RobertaEnv

register(
    id='RobertaEnv-v0',
    entry_point='robertaEnv:RobertaEnv',
    max_episode_steps=10000,
)

# %%
from gymnasium.utils.env_checker import check_env

env = gym.make('RobertaEnv-v0')
check_env(env)
# Out:
# /home/andreassis/RobertaIA/.venv/lib/python3.12/site-packages/gymnasium/utils/env_checker.py:390: UserWarning: WARN: The environment (<TimeLimit<OrderEnforcing<PassiveEnvChecker<RobertaEnv<RobertaEnv-v0>>>>>) is different from the unwrapped version (<RobertaEnv<RobertaEnv-v0>>). This could effect the environment checker as the environment most likely has a wrapper applied to it. We recommend using the raw environment for `check_env` using `env.unwrapped`.
#   logger.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from gymnasium.utils.env_checker import check_env
#       2
#       3 env = gym.make('RobertaEnv-v0')
# ----> 4 check_env(env)
#
# File ~/RobertaIA/.venv/lib/python3.12/site-packages/gymnasium/utils/env_checker.py:436, in check_env(env, warn, skip_render_check, skip_close_check)
#     434 for render_mode in env.metadata["render_modes"]:
#     435     new_env = env.spec.make(render_mode=render_mode)
# --> 436     new_env.reset()
#     437     env_render_passive_checker(new_env)
#     438     new_env.close()
#
# File ~/RobertaIA/.venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:145, in TimeLimit.reset(self, seed, options)
#     135 """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#     136
#     137 Args:
#    (...)    142     The reset environment
#     143 """
#     144 self._elapsed_steps = 0
# --> 145 return super().reset(seed=seed, options=options)
#
# File ~/RobertaIA/.venv/lib/python3.12/site-packages/gymnasium/core.py:333, in Wrapper.reset(self, seed, options)
#     329 def reset(
#     330     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     331 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     332     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 333     return self.env.reset(seed=seed, options=options)
#
# File ~/RobertaIA/.venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:399, in OrderEnforcing.reset(self, seed, options)
#     397 """Resets the environment with `kwargs`."""
#     398 self._has_reset = True
# --> 399 return super().reset(seed=seed, options=options)
#
# File ~/RobertaIA/.venv/lib/python3.12/site-packages/gymnasium/core.py:333, in Wrapper.reset(self, seed, options)
#     329 def reset(
#     330     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     331 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     332     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 333     return self.env.reset(seed=seed, options=options)
#
# File ~/RobertaIA/.venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:292, in PassiveEnvChecker.reset(self, seed, options)
#     290 if self.checked_reset is False:
#     291     self.checked_reset = True
# --> 292     return env_reset_passive_checker(self.env, seed=seed, options=options)
#     293 else:
#     294     return self.env.reset(seed=seed, options=options)
#
# File ~/RobertaIA/.venv/lib/python3.12/site-packages/gymnasium/utils/passive_env_checker.py:184, in env_reset_passive_checker(env, **kwargs)
#     179     logger.deprecation(
#     180         "Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information."
#     181     )
#     183 # Checks the result of env.reset with kwargs
# --> 184 result = env.reset(**kwargs)
#     186 if not isinstance(result, tuple):
#     187     logger.warn(
#     188         f"The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `{type(result)}`"
#     189     )
#
# File ~/RobertaIA/src/robertaEnv.py:153, in RobertaEnv.reset(self, seed, options)
#     150 self.steps_beyond_terminated = None
#     152 if self.render_mode == "human":
# --> 153     self.render()
#     154 return self.state, {}
#
# File ~/RobertaIA/src/robertaEnv.py:217, in RobertaEnv.render(self)
#     214 p4_x = (cosphi * armlen - senphi * armwi / 2) * scale
#     215 p4_y = (senphi * armlen + cosphi * armwi / 2) * scale
# --> 217 c1 = (int(float(center_x + p1_x)), int(float(center_y - p1_y)))
#     218 c2 = (int(float(center_x + p2_x)), int(float(center_y - p2_y)))
#     219 c3 = (int(float(center_x + p3_x)), int(float(center_y - p3_y)))
#
# TypeError: only 0-dimensional arrays can be converted to Python scalars
